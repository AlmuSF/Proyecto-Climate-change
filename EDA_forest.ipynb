# %%
import pandas as pd

# %%
df_forest= pd.read_csv('forest_area_percent.csv')

# %%
df_forest.sample(25)
# Out:
#                     Country Name Country Code       1990       1991  \
# 41                         China          CHN  16.738007  16.949547
# 11                       Austria          AUT  45.754605  45.830308
# 121                   Mauritania          MRT   0.461861   0.456583
# 112                    Lithuania          LTU        NaN        NaN
# 138                      Nigeria          NGA  29.124905  28.945601
# 38                          Chad          TCD   5.344663   5.314724
# 182         Syrian Arab Republic          SYR   2.024595   2.057242
# 113                   Luxembourg          LUX        NaN        NaN
# 25                      Botswana          BWA  33.179292  32.970550
# 99                         Kenya          KEN   6.779597   6.797633
# 172                        Spain          ESP  27.840501  28.479071
# 247  Pacific island small states          PSS  65.449570  65.902274
# 65                 Faroe Islands          FRO   0.057307   0.057307
# ...

# %%
# Eliminar la columna 'country_code' y las columnas desde '1990' hasta '2011'
df_forest = df_forest.drop(columns=['Country Code'] + [str(year) for year in range(1990, 2012)])

# %%
df_forest.head()
# Out:
#      Country Name       2012       2013       2014       2015       2016  \
# 0     Afghanistan   1.852782   1.852782   1.852782   1.852782   1.852782
# 1         Albania  28.646606  28.698558  28.750511  28.802464  28.802190
# 2         Algeria   0.811675   0.814866   0.818057   0.821248   0.821248
# 3  American Samoa  86.850000  86.700000  86.550000  86.400000  86.250000
# 4         Andorra  34.042553  34.042553  34.042553  34.042553  34.042553
#
#         2017       2018       2019       2020       2021
# 0   1.852782   1.852782   1.852782   1.852782   1.852782
# 1  28.792062  28.791971  28.791971  28.791971  28.791971
# 2   0.815790   0.810332   0.814110   0.818309   0.822228
# 3  86.100000  85.950000  85.800000  85.650000  85.500000
# 4  34.042553  34.042553  34.042553  34.042553  34.042553

# %%
total_valores_country= df_forest["Country Name"].nunique()

# %%
total_valores_country
# Out:
# 258

# %%
print(df_forest.columns)
# Out:
# Index(['Country Name', '2012', '2013', '2014', '2015', '2016', '2017', '2018',
#        '2019', '2020', '2021'],
#       dtype='object')

# %%
print(df_forest.columns.tolist())
# Out:
# ['Country Name', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021']

# %%
df_forest.columns.get_loc("Country Name")
# Out:
# 0

# %%
df_forest.sample(50)
# Out:
#                                           Country Name       2012       2013  \
# 134                                      New Caledonia  45.887309  45.881838
# 174                                St. Kitts and Nevis  42.307692  42.307692
# 218         East Asia & Pacific (IDA & IBRD countries)  29.955364  29.992934
# 219                                          Euro area  38.137422  38.199410
# 194                                             Tuvalu  33.333333  33.333333
# 221      Europe & Central Asia (excluding high income)  39.421199  39.431636
# 66                                                Fiji  59.474111  59.839518
# 79                                           Guatemala  34.228070  33.972751
# 0                                          Afghanistan   1.852782   1.852782
# 164                                          Singapore  24.409065  24.015559
# 172                                              Spain  37.079778  37.082114
# ...

# %%
df_forest['Country Name'].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'American Samoa', 'Andorra',
#        'Angola', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba',
#        'Australia', 'Austria', 'Azerbaijan', 'Bahamas, The', 'Bahrain',
#        'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin',
#        'Bermuda', 'Bhutan', 'Bolivia', 'Bosnia and Herzegovina',
#        'Botswana', 'Brazil', 'British Virgin Islands',
#        'Brunei Darussalam', 'Bulgaria', 'Burkina Faso', 'Burundi',
#        'Cabo Verde', 'Cambodia', 'Cameroon', 'Canada', 'Cayman Islands',
#        'Central African Republic', 'Chad', 'Channel Islands', 'Chile',
#        'China', 'Colombia', 'Comoros', 'Congo, Dem. Rep.', 'Congo, Rep.',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Curacao',
#        'Cyprus', 'Czechia', 'Denmark', 'Djibouti', 'Dominica',
#        'Dominican Republic', 'Ecuador', 'Egypt, Arab Rep.', 'El Salvador',
# ...

# %%
nulos_por_columna = df_forest.isnull().sum()
print("Nulos por columna:")
print(nulos_por_columna)
# Out:
# Nulos por columna:
# Country Name    0
# 2012            0
# 2013            0
# 2014            0
# 2015            0
# 2016            0
# 2017            0
# 2018            0
# 2019            0
# 2020            0
# 2021            0
# dtype: int64

# %%
duplicados_por_columna = df_forest.apply(lambda col: col.duplicated().sum())
print("\nDuplicados por columna:")
print(duplicados_por_columna)
# Out:
# Duplicados por columna:
# Country Name    0
# 2012            2
# 2013            2
# 2014            2
# 2015            2
# 2016            2
# 2017            2
# 2018            2
# 2019            2
# 2020            2
# 2021            2
# dtype: int64

# %%
df_ordenado = df_forest.sort_values(by="Country Name", ascending=True)

# %%
df_ordenado.head(30)
# Out:
#                     Country Name       2012       2013       2014       2015  \
# 0                    Afghanistan   1.852782   1.852782   1.852782   1.852782
# 210  Africa Eastern and Southern  31.890654  31.680635  31.470634  31.260420
# 211   Africa Western and Central  20.498099  20.410143  20.322187  20.234231
# 1                        Albania  28.646606  28.698558  28.750511  28.802464
# 2                        Algeria   0.811675   0.814866   0.818057   0.821248
# 3                 American Samoa  86.850000  86.700000  86.550000  86.400000
# 4                        Andorra  34.042553  34.042553  34.042553  34.042553
# 5                         Angola  56.988751  56.543526  56.098301  55.653076
# 6            Antigua and Barbuda  19.654545  19.504545  19.354545  19.204545
# 212                   Arab World   2.956405   2.937937   2.919452   2.900938
# 7                      Argentina  10.877081  10.795450  10.713819  10.632187
# ...

# %%
df_forest.to_csv("Forest_percent.csv", index=False)

# %%
import pandas as pd

# %%
df_forest_pbi = df_ordenado.melt(id_vars=["Country Name"], var_name="Año", value_name="Porcentaje_Forestal")

# %%
df_forest_pbi
# Out:
#                      Country Name   Año  Porcentaje_Forestal
# 0                     Afghanistan  2012             1.852782
# 1     Africa Eastern and Southern  2012            31.890654
# 2      Africa Western and Central  2012            20.498099
# 3                         Albania  2012            28.646606
# 4                         Algeria  2012             0.811675
# ...                           ...   ...                  ...
# 2575           West Bank and Gaza  2021             1.682988
# 2576                        World  2021            31.177049
# 2577                  Yemen, Rep.  2021             1.039832
# 2578                       Zambia  2021            60.030150
# 2579                     Zimbabwe  2021            44.974822
#
# [2580 rows x 3 columns]

# %%
df_forest_pbi.

# %%
df_forest_pbi.to_csv("Forest_percent_pbi.csv", index=False)
